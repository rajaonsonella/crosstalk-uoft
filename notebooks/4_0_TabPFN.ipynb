# %% [markdown]
# # TabPFN

# %% [markdown]
# # Set up

# %% [markdown]
# ⚙️ Step 1: Set your notebook to GPU

# %% [markdown]
# The next two cells take ~2 min.... start running them now while we talk! 👇👇

# %%
# get workshop code
import os
import sys
IN_COLAB = os.getenv("COLAB_RELEASE_TAG")
if IN_COLAB:
    # !git clone https://github.com/rajaonsonella/crosstalk-uoft
    sys.path.append('./crosstalk-uoft')
else:
    sys.path.append('..')
# !pip install -r crosstalk-uoft/requirements.txt
# !pip install tabpfn
# Out:
# fatal: destination path 'crosstalk-uoft' already exists and is not an empty directory.
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 4)) (5.2.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 5)) (1.2.8)
# Requirement already satisfied: pympler in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 6)) (1.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 7)) (0.13.2)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 8)) (2025.9.1)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.12/dist-packages (from -r crosstalk-uoft/requirements.txt (line 9)) (0.5.9.post2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r crosstalk-uoft/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r crosstalk-uoft/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r crosstalk-uoft/requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r crosstalk-uoft/requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r crosstalk-uoft/requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r crosstalk-uoft/requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->-r crosstalk-uoft/requirements.txt (line 4)) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->-r crosstalk-uoft/requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown->-r crosstalk-uoft/requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->-r crosstalk-uoft/requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost->-r crosstalk-uoft/requirements.txt (line 5)) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost->-r crosstalk-uoft/requirements.txt (line 5)) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost->-r crosstalk-uoft/requirements.txt (line 5)) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost->-r crosstalk-uoft/requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit->-r crosstalk-uoft/requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn->-r crosstalk-uoft/requirements.txt (line 9)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn->-r crosstalk-uoft/requirements.txt (line 9)) (0.5.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (3.2.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn->-r crosstalk-uoft/requirements.txt (line 9)) (0.43.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost->-r crosstalk-uoft/requirements.txt (line 5)) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->-r crosstalk-uoft/requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: tabpfn in /usr/local/lib/python3.12/dist-packages (6.0.6)
# Requirement already satisfied: torch<3,>=2.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.8.0+cu126)
# Requirement already satisfied: numpy<3,>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.0.2)
# Requirement already satisfied: scikit-learn<1.8,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.6.1)
# Requirement already satisfied: typing_extensions>=4.12.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (4.15.0)
# Requirement already satisfied: scipy<2,>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.16.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.2.2)
# Requirement already satisfied: einops<0.9,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.8.1)
# Requirement already satisfied: huggingface-hub<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.36.0)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.11.10)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (2.12.0)
# Requirement already satisfied: eval-type-backport>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (0.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.5.2)
# Requirement already satisfied: tabpfn-common-utils>=0.2.7 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (0.2.9)
# Requirement already satisfied: kditransform>=1.2 in /usr/local/lib/python3.12/dist-packages (from tabpfn) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2,>=0.19.0->tabpfn) (1.2.0)
# Requirement already satisfied: numba>=0.48 in /usr/local/lib/python3.12/dist-packages (from kditransform>=1.2->tabpfn) (0.60.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->tabpfn) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->tabpfn) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.10.1->tabpfn) (1.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<1.8,>=1.2.0->tabpfn) (3.6.0)
# Requirement already satisfied: platformdirs>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (4.5.0)
# Requirement already satisfied: posthog~=6.7 in /usr/local/lib/python3.12/dist-packages (from tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (6.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.1->tabpfn) (3.4.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.48->kditransform>=1.2->tabpfn) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog~=6.7->tabpfn-common-utils>=0.2.7->tabpfn-common-utils[telemetry-interactive]>=0.2.7->tabpfn) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2,>=0.19.0->tabpfn) (2025.10.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.1->tabpfn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.1->tabpfn) (3.0.3)

# %%
# Download data from google drive
import gdown
import os

file_ids = {'test' : '1Gyv_ldUTi0Ymy6wVMfruAO0UraCQ70CR',
            'train':'11S5p0QgP1X9rOFiIjNSLydLenJwm7hle'}

for name, file_id in file_ids.items():
    filename = f'crosstalk_{name}.parquet'
    if not os.path.exists(filename):
        gdown.download(id=file_id, output=filename, quiet=False)

# %% [markdown]
# We had a problem with too many requests on the shared data file. If you get an error with the above, you may be able to upload the file to your google drive, you can locate it with the following. Then, adjust file paths, eg. `content/drive/My Drive/crosstalk_train.parquet`

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## 📈 Load the data

# %%
# package to efficiently read in data from parquet file
from pyarrow.parquet import ParquetFile
import pyarrow as pa
import pyarrow.parquet as pq

# packages to help us with data manipulation in tables
import pandas as pd
import numpy as np
import scipy
#
from tqdm.auto import tqdm
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
# TabPFN
import tabpfn
from tabpfn import TabPFNClassifier
from tabpfn.constants import ModelVersion
import more_itertools
import dataset

# %% [markdown]
# This is a large file, so we won't load the whole thing into memory all at once. Parquet has some nice utilities for telling us some info about the dataset, without having to actually load it.

# %%
# Get parquet file
pf = ParquetFile('crosstalk_train.parquet')

# %%
# How many rows and columns?
N = pf.metadata.num_rows
print(pf.metadata)
# Out:
# <pyarrow._parquet.FileMetaData object at 0x7ee880716d40>
#   created_by: parquet-cpp-arrow version 17.0.0
#   num_columns: 16
#   num_rows: 375595
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 53693

# %%
# What are the column names?
print(pf.schema.names)
# Out:
# ['ID', 'DEL_ID', 'DELLabel', 'RawCount', 'Target', 'ECFP4', 'ECFP6', 'FCFP4', 'FCFP6', 'MACCS', 'RDK', 'AVALON', 'ATOMPAIR', 'TOPTOR', 'MW', 'ALOGP']

# %% [markdown]
# ## Incremental learning with batches
#
# We'll write a data loader which will take each batch by iterating through the parquet file. Note: this only works for models which support incremental learning, which not all do.
#
# We also take care of train/test split *inside* the dataloader in this case, because we are loading it incrementally.

# %% [markdown]
# ⚠️ This cell takes a long time to run so we cut it off early for demo purposes. If you use it in your own code be sure to increase the `max_batches` in order to see all the data

# %%
batch_size = 1024
n_batches = N // batch_size
max_batches = None
iterator = dataset.parquet_split_dataloader("crosstalk_train.parquet", "ECFP6", "DELLabel",
                                    chunk_size=batch_size)

# %%
model = SGDClassifier(loss="log_loss")

# %%
first = True
test_x_list = []
test_y_list = []
for (x_train, y_train), (x_test, y_test) in tqdm(iterator, total = n_batches):
    if first:
        model.partial_fit(x_train, y_train, classes=[0, 1])
        first = False
    else:
        model.partial_fit(x_train, y_train)
    test_x_list.append(x_test)
    test_y_list.append(y_test)
# Out:
#   0%|          | 0/366 [00:00<?, ?it/s]
# CPU times: user 2min 9s, sys: 1.12 s, total: 2min 11s
# Wall time: 2min 13s

# %%
  # Evaluate
  y_pred = model.predict_proba(x_test)[:, 1]
  auc = roc_auc_score(y_test,  y_pred )
  auprc = average_precision_score(y_test,  y_pred )
  print(f"AUROC: {auc:.4f}")
  print(f"AUPRC: {auprc:.4f}")
# Out:
# AUROC: 0.9331
# AUPRC: 0.6727

# %% [markdown]
# # TabPFN

# %%
x = dataset.load_x("crosstalk_train.parquet", ["ECFP6"])
y = dataset.load_y("crosstalk_train.parquet")

print(x.shape, y.shape)
# Out:
# Total rows: 375595
# Expected Memory for inputs: 2.87 GBs
#   0%|          | 0/375 [00:00<?, ?it/s]
# (375595, 2048) (375595, 1)

# %% [markdown]
# Downsample feature dimension

# %%
feat_dim = 250
og_dim = x.shape[1]
assert feat_dim < og_dim, "Check your dims!"
feat_mask = np.zeros(og_dim, dtype=bool)
selected_indices = np.random.choice(og_dim, feat_dim, replace=False)
feat_mask[selected_indices] = True
x = x[:, feat_mask]

# %% [markdown]
# Downsample samples

# %%
n_samples = 5000

x_train, x_val, y_train, y_val = train_test_split(
    x,
    y,
    train_size=n_samples,
    stratify=y,
    random_state=42
)
print(x_train.shape, y_train.shape)
# Out:
# (5000, 250) (5000, 1)

# %% [markdown]
# Create a model

# %%
model = TabPFNClassifier.create_default_for_version(ModelVersion.V2)

# %% [markdown]
# tabpfn only support medium sized datasets!

# %%
model.fit(x_train, y_train.ravel())
# Out:
# TabPFNClassifier(model_path='/root/.cache/tabpfn/tabpfn-v2-classifier-finetuned-zk73skhh.ckpt')

# %%
batch_size = 1024
y_pred = []
n_val = len(x_val)
iterator = more_itertools.chunked(list(range(n_val)), batch_size)
n_chunks = n_val // batch_size
for chunk in tqdm(iterator, total=n_chunks):
  #indices = np.bsta
  y_pred.append(model.predict_proba(x_val[chunk])[:, 1])
y_preds = np.hstack(y_pred)
print(y_preds.shape)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# (370,)

# %% [markdown]
# Evals

# %%
auc = roc_auc_score(y_test,  y_pred )
auprc = average_precision_score(y_test,  y_pred )
print(f"AUROC: {auc:.4f}")
print(f"AUPRC: {auprc:.4f}")
